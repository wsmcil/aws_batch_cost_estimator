# %%
#!/usr/bin/env python3

# AWS Batch Cost Estimator
#
# Reads input CMDB information from a traditional data center to size and cost estimate AWS EC2 & RDS
# infrastructure.
#
# Prerequisites:
# 1. Python3
# 2. AWS Python SDK (Boto3)
# 3. Pandas Python library
# 4. json Python library
# 5. re Python libary

# Load libraries
import pandas as pd
import json
import boto3
import re
import pdb

# Configuration variables
fileInput='cmdb.csv'
fileOutput='aws_bom.csv'

# Input column mappings

# Column which indicates source cores and peak load
srcCores = 'CPU'
srcCPUUsage = 'Peak CPU Load'

# Column which indicates peak memory useage in MB
# If srcMemUsed is blank or zero, the script will use srcMemProvsioned as the target memory
srcMemProvisioned = 'Mem (MB)'
srcMemUsed = 'Peak Mem Used'

# Columns indicating environment (dev, test, prod, etc.)
srcEnv = 'Current State Services'
DEV = 'Dev'
QA = 'QA'
TEST = 'Test'

# Region mappings, including using a default region if not specified as europe or asia
srcRegion='Target Region'
srcASIA="AP"
awsASIA="ap-northeast-2"
srcEU='EU'
awsEU='eu-central-1'
awsDFLT='us-east-1'
awsLocDFLT="US East (N. Virginia)"
awsLocEU="EU (Frankfurt)"
awsLocASIA="Asia Pacific (Seoul)"

# OS platforms for AWS.  The customer source is all over the board and requires some manual
# tweaking.  So far only coded for Windows, RHEL, and Amazon Linux (default)
srcOS='Platform'
srcOSVer='OS Ver'
awsWindows="Windows"
awsRHEL="RHEL"
awsDefault="Linux"

# Compute families.  These are super families.  X and T are actually subfamilies in the pricing API
awsComputeOptimized="Compute optimized"
awsMemoryOptimized="Memory optimized"
awsGeneralPurpose="General purpose"

# Database mappings

# Column which determines if a configuration item is an RDS candidate
# Non zero value in this column indicates a database present
srcDbInstanceCount = 'DB Instance Count'

# Dataase constants
srcOracle="Oracle"
srcSQLServer="SQL "
srcDB="DB Rel/Ver"
awsOracle="Oracle"
awsSQLServer="SQL Server"
awsAurora="Aurora MySQL"

# Fixed rates for block storage
ec2EBSUnitCost=.151
rdsEBSUnitCost=.116
srcBlockStorage='Fixed Used Size (GB)'

# Open input file, read into frame
print("Reading input file....")
dfCMDB = pd.read_csv(fileInput, keep_default_na=False)

#Add RDS Column
print("Determining RDS targets....")
dfCMDB['RDS']=False

# List the servers with database instances along with type, flag as targets for RDS service
dfDBServers = dfCMDB[dfCMDB[srcDbInstanceCount] != ""]
dfDBServers = dfDBServers[dfDBServers[srcDbInstanceCount] !="0"]

indexes=dfDBServers.index.tolist()

for row in indexes:
    dfCMDB.loc[row, 'RDS'] = True
    
# Calculate cores needed from peak CPU
print("Calculating target EC2 cores...")
dfCMDB['cores_calc'] = (dfCMDB[srcCores] * dfCMDB[srcCPUUsage]) + .51
dfCMDB['cores_calc']=dfCMDB['cores_calc'].round(decimals=0)

# Correct missing used memory
for index in dfCMDB.index.tolist():
    if dfCMDB.loc[index, srcMemUsed] == 0:
        dfCMDB.loc[index, srcMemUsed] = dfCMDB.loc[index, srcMemProvisioned]
        
# Create family inference column
print("Determining EC2 instance families...")
dfCMDB['calc_family'] = ""

# Make an inference for ec2 family
dfCMDB['mem_cpu_ratio'] = dfCMDB[srcMemUsed] / dfCMDB['cores_calc']

for index in dfCMDB.index.tolist():
    if ((dfCMDB.loc[index, 'cores_calc'] <= 8) and (dfCMDB.loc[index, srcMemUsed] <=32)
        and (DEV in dfCMDB.loc[index, srcEnv]
             or QA in dfCMDB.loc[index, srcEnv]
             or TEST in dfCMDB.loc[index, srcEnv])):
            dfCMDB.loc[index, 'calc_family'] = "t"
            
    elif (dfCMDB.loc[index, 'mem_cpu_ratio'] < 3.5):
             dfCMDB.loc[index, 'calc_family'] = "c"
            
    elif (dfCMDB.loc[index, 'mem_cpu_ratio'] > 4.5):
             dfCMDB.loc[index, 'calc_family'] = "r"
            
    else:
             dfCMDB.loc[index, 'calc_family'] = "m"
            

            
# Create AWS Region Column and map to source region
# ap-northeast-2
# us-east-1
# eu-central-1
dfCMDB['AWS_Region'] = ""

print ("Mapping regions...")

for index in dfCMDB.index.tolist():
    if dfCMDB.loc[index, srcRegion] == srcASIA:
        dfCMDB.loc[index, 'AWS_Region'] = awsASIA
    elif dfCMDB.loc[index, srcRegion] == srcEU:
        dfCMDB.loc[index, 'AWS_Region'] = awsEU
    else:
        dfCMDB.loc[index, 'AWS_Region'] = awsDFLT
        
# Create AWS OS column, search for key words in source os to map to EC2 platform

print ("Determining OS platforms...")
dfCMDB['AWS_OS'] = ""

# This code required manual tweaking to account for the different representations of RedHat
for index in dfCMDB.index.tolist():
    if "Windows" in dfCMDB.loc[index, srcOS]:
        dfCMDB.loc[index, 'AWS_OS'] = awsWindows
    elif "Linux" in dfCMDB.loc[index, srcOS]:
        if ("RHEL" in dfCMDB.loc[index, srcOSVer] or
            "Red" in dfCMDB.loc[index, srcOSVer] or
            "RED" in dfCMDB.loc[index, srcOSVer]):
                dfCMDB.loc[index, 'AWS_OS'] = awsRHEL
        else:
            dfCMDB.loc[index, 'AWS_OS'] = awsDefault
    else:
        dfCMDB.loc[index, 'AWS_OS'] = awsDefault
        
# Core matching and pricing code
# Match calculated capacity requirements to EC2 instance types
# Price resulting EC2 instance types by hour, year, and 3-year RIs

print('Pricing EC2 instances....')

# Core matching and pricing code
# Match calculated capacity requirements to EC2 instance types
# Price resulting EC2 instance types by hour, year, and 3-year RIs

regions = {awsDFLT, awsEU, awsASIA}
families = {"m", "c", "r", "t"}
oses = {awsWindows, awsRHEL, awsDefault}

for region in regions:
    print("Region " +region)
    for os in oses:
        print("OS " + os)
        for family in families:
            print("Family " +family)
            # Lets get specific and only get the license included, no pre-installed software, current generation, etc.
            client = boto3.client('pricing')
            
            if region == awsDFLT:
                location = awsLocDFLT
            elif region == awsEU:
                location = awsLocEU
            else:
                location = awsLocASIA
            
            if family == "c":
                instanceFamily = awsComputeOptimized
            elif family == "r":
                instanceFamily = awsMemoryOptimized
            else:
                instanceFamily = awsGeneralPurpose
    
            response = client.get_products(
                Filters=[
                    {
                        'Type': 'TERM_MATCH',
                        'Field': 'location',
                        'Value': location
                    },
                    {
                        'Type': 'TERM_MATCH',
                        'Field': 'operatingSystem',
                        'Value': os
                    },
                    {
                        'Type': 'TERM_MATCH',
                        'Field': 'instanceFamily',
                        'Value': instanceFamily
                    },
                    {
                        'Type': 'TERM_MATCH',
                        'Field': 'currentGeneration',
                        'Value': 'Yes'
                    },
                    {
                        'Type': 'TERM_MATCH',
                        'Field': 'licenseModel',
                        'Value': 'No License required'
                    },
                    {
                        'Type': 'TERM_MATCH',
                        'Field': 'tenancy',
                        'Value': 'Shared'
                    },
                    {
                        'Type': 'TERM_MATCH',
                        'Field': 'preInstalledSw',
                        'Value': 'NA'
                    }
                ],
                ServiceCode='AmazonEC2',
                MaxResults=100
            )
        
            # Let's parse the JSON and get the elements we need to map to EC2 instance type
            items=response['PriceList']


            # Lets make a dataframe with the EC2 instance choices that are rhel and memory optimized
            d={'instanceType':[], 'memory':[], 'family':[], 'one_hr_rate':[], 'one_yr_rate':[], 'three_yr_rate':[], 'vcpu':[]}
            dfInstanceList=pd.DataFrame(data=d)
            index=0

            for item in items:
                skip = False;
                jItem=json.loads(item)
                itemAttributes=jItem['product']['attributes']
                instanceType=itemAttributes['instanceType']
                instancefamily=instanceType[0:2]
                
                # Filter out the new m5d types
                if (instanceType[0:3] == "m5d"):
                    skip = True;
                
                if ((instancefamily != "c3") and (instancefamily != "m3") and (skip != True)):
                    vcpu=itemAttributes['vcpu']
                    sku=jItem['product']['sku']
                    ondemandterm="JRTCKXETXF"
                    ondemandratecode="6YS6EN2CT7"
                    oneyearterm="6QCMYABX3D"
                    oneyearratecode="2TG2D8R56U"
                    threeyearterm="NQ3QZPMQV9"
                    threeyearratecode="2TG2D8R56U"
                    onehr_rate=jItem['terms']['OnDemand'][sku+"."+ondemandterm]['priceDimensions'][sku+"."+ondemandterm+"."+ondemandratecode]['pricePerUnit']['USD']
                    oneyr_rate=jItem['terms']['Reserved'][sku+"."+oneyearterm]['priceDimensions'][sku+"."+oneyearterm+"."+oneyearratecode]['pricePerUnit']['USD']
                    threeyr_rate=jItem['terms']['Reserved'][sku+"."+threeyearterm]['priceDimensions'][sku+"."+threeyearterm+"."+threeyearratecode]['pricePerUnit']['USD']
                
                # Drop the old lines
                if (family == "t"):
                    if (instancefamily[0] != "m"):
                        memoryelement=itemAttributes['memory']
                        memory=re.sub('[^0-9]','', memoryelement)
                        dfInstanceList.loc[index, 'instanceType'] = itemAttributes['instanceType']
                        dfInstanceList.loc[index, 'memory'] =  memory
                        dfInstanceList.loc[index,'family'] = family
                        dfInstanceList.loc[index, 'vcpu'] = vcpu 
                        dfInstanceList.loc[index, 'one_hr_rate'] = onehr_rate
                        dfInstanceList.loc[index, 'one_yr_rate'] = oneyr_rate
                        dfInstanceList.loc[index, 'three_yr_rate'] = threeyr_rate
                        index=index+1


                elif (region == awsDFLT):
                    if ((instancefamily != "m4") and (instancefamily != "m3") and (instancefamily != "c4") and (instancefamily !="c3") and (instancefamily != "r3") and (instancefamily != "t2") and (skip != True)):
                        memoryelement=itemAttributes['memory']
                        memory=re.sub('[^0-9]','', memoryelement)
                        dfInstanceList.loc[index, 'instanceType'] = itemAttributes['instanceType']
                        dfInstanceList.loc[index, 'memory'] =  memory
                        dfInstanceList.loc[index,'family'] = family
                        dfInstanceList.loc[index,'vcpu'] = vcpu
                        dfInstanceList.loc[index, 'one_hr_rate'] = onehr_rate
                        dfInstanceList.loc[index, 'one_yr_rate'] = oneyr_rate
                        dfInstanceList.loc[index, 'three_yr_rate'] = threeyr_rate
                        index=index+1

                else:
                    if ((instancefamily != "m3") and (instancefamily != "c3") and (instancefamily != "r3") and (instancefamily != "t2") and (skip != True)):
                        memoryelement=itemAttributes['memory']
                        memory=re.sub('[^0-9]','', memoryelement)
                        dfInstanceList.loc[index, 'instanceType'] = itemAttributes['instanceType']
                        dfInstanceList.loc[index, 'memory'] =  memory
                        dfInstanceList.loc[index,'family'] = family
                        dfInstanceList.loc[index, 'vcpu'] = vcpu
                        dfInstanceList.loc[index, 'one_hr_rate'] = onehr_rate
                        dfInstanceList.loc[index, 'one_yr_rate'] = oneyr_rate
                        dfInstanceList.loc[index, 'three_yr_rate'] = threeyr_rate
                        index=index+1
            
            #Convert memory to numeric
            dfInstanceList['memory']=dfInstanceList['memory'].apply(pd.to_numeric)
            dfInstanceList['vcpu']=dfInstanceList['vcpu'].apply(pd.to_numeric)
            dfInstanceList['one_hr_rate']=dfInstanceList['one_hr_rate'].apply(pd.to_numeric)
            dfInstanceList['one_yr_rate']=dfInstanceList['one_yr_rate'].apply(pd.to_numeric)
            dfInstanceList['three_yr_rate']=dfInstanceList['three_yr_rate'].apply(pd.to_numeric)

            dfInstanceList_sorted=dfInstanceList.sort_values(by=['vcpu'], ascending=True)
            dfInstanceList_sorted=dfInstanceList_sorted.reset_index(drop=True)
                    
            dfCMDB_filter = dfCMDB[(dfCMDB.calc_family == family) & (dfCMDB.AWS_OS == os) & (dfCMDB.RDS == False) & (dfCMDB.AWS_Region == region)]

            # Map instances to EC2 instance types  

            for index in dfCMDB_filter.index.tolist():
                found=False
                instance=0

                while ((not(found)) & (instance < len(dfInstanceList_sorted))):
                    if ((dfInstanceList_sorted.loc[instance, 'memory'] >= dfCMDB.loc[index, srcMemUsed]) and (dfInstanceList_sorted.loc[instance, 'vcpu'] >= dfCMDB.loc[index, 'cores_calc'])):
                        found = True
                        dfCMDB.loc[index, 'ec2_instance_type'] = dfInstanceList_sorted.loc[instance, 'instanceType']
                        dfCMDB.loc[index, 'one_hr_rate'] = dfInstanceList_sorted.loc[instance, 'one_hr_rate']
                        dfCMDB.loc[index, 'one_yr_rate'] = dfInstanceList_sorted.loc[instance, 'one_yr_rate']
                        dfCMDB.loc[index, 'three_yr_rate'] = dfInstanceList_sorted.loc[instance, 'three_yr_rate']

                    instance = instance +1
                    

                    
# Review and price RDS                    
# Map source DB to AWS_DB

dfCMDB['AWS_DB'] = "" 
dfCMDB_filterrds = dfCMDB[(dfCMDB.RDS == True)]   
   
indexes=dfCMDB_filterrds.index.tolist()
for row in indexes:
    if srcOracle in dfCMDB.loc[row, srcDB]:
        dfCMDB.loc[row, 'AWS_DB'] = awsOracle
    elif srcSQLServer in dfCMDB.loc[row, srcDB]:
        dfCMDB.loc[row, 'AWS_DB'] = awsSQLServer
    else:
        dfCMDB.loc[row, 'AWS_DB'] = awsAurora
        
# Map RDS instances
#regions = {"us-east-1", "eu-central-1", "ap-northeast-2"}
#families = {"m", "c", "r", "t"}
dbs = {awsOracle, awsSQLServer, awsAurora}

print('Pricing RDS...')

for region in regions:
    print('Region ' + region)
    for db in dbs:
        print('DB ' + db)
        for family in families:
            print('Family ' + family)
            # Lets get specific and only get the license included, no pre-installed software, current generation, etc.
            client = boto3.client('pricing')
            
            if region == awsDFLT:
                location = awsLocDFLT
            elif region == awsEU:
                location = awsLocEU
            else:
                location = awsLocASIA
            
            if family == "r":
                instanceFamily = awsMemoryOptimized
            else:
                instanceFamily = awsGeneralPurpose
                
            if db == awsAurora:
                licensemodel="No license required"
                instanceFamily = awsMemoryOptimized
            else:
                licensemodel="License included"
    
            response = client.get_products(
                Filters=[
                    {
                        'Type': 'TERM_MATCH',
                        'Field': 'location',
                        'Value': location
                    },
                    {
                        'Type': 'TERM_MATCH',
                        'Field': 'databaseEngine',
                        'Value': db
                    },
                    {
                        'Type': 'TERM_MATCH',
                        'Field': 'currentGeneration',
                        'Value': 'Yes'            
                    },
                    {
                        'Type': 'TERM_MATCH',
                        'Field': 'instanceFamily',
                        'Value': instanceFamily          
                    },      
                    {
                        'Type': 'TERM_MATCH',
                        'Field': 'licenseModel',
                        'Value': licensemodel            
                    }, 
                    ],                
                    ServiceCode='AmazonRDS',
                    MaxResults=100
                )
        
            # Let's parse the JSON and get the elements we need to map to EC2 instance type
            items=response['PriceList']

            # Lets make a dataframe with the RDS instance choices
            d={'instanceType':[], 'memory':[], 'family':[], 'one_hr_rate':[], 'one_yr_rate':[], 'three_yr_rate':[], 'vcpu':[]}
            dfInstanceList=pd.DataFrame(data=d)
            index=0

            for item in items:
                jItem=json.loads(item)
                itemAttributes=jItem['product']['attributes']
                instanceType=itemAttributes['instanceType']
                instancefamily=instanceType[3:5]
                vcpu=itemAttributes['vcpu']
                sku=jItem['product']['sku']
                ondemandterm="JRTCKXETXF"
                ondemandratecode="6YS6EN2CT7"
                
                if (db == awsSQLServer):
                    oneyearterm="HU7G6KETJZ"
                else:
                    oneyearterm="6QCMYABX3D"
                
                oneyearratecode="2TG2D8R56U"
                onyearratecode="6YS6EN2CT7"
                threeyearterm="NQ3QZPMQV9"
                threeyearratecode="2TG2D8R56U"
                onehr_rate=jItem['terms']['OnDemand'][sku+"."+ondemandterm]['priceDimensions'][sku+"."+ondemandterm+"."+ondemandratecode]['pricePerUnit']['USD']
                oneyr_rate=jItem['terms']['Reserved'][sku+"."+oneyearterm]['priceDimensions'][sku+"."+oneyearterm+"."+oneyearratecode]['pricePerUnit']['USD']
                
                # Account for the absence of an 'one-year all up-front' option for SQL server
                if db == awsSQLServer:  
                    sqlhourly=float(jItem['terms']['Reserved'][sku+"."+oneyearterm]['priceDimensions'][sku+"."+oneyearterm+"."+ondemandratecode]['pricePerUnit']['USD'])
                    oneyr_rate = float(oneyr_rate) + (sqlhourly * 8760)

                threeyr_rate=jItem['terms']['Reserved'][sku+"."+threeyearterm]['priceDimensions'][sku+"."+threeyearterm+"."+threeyearratecode]['pricePerUnit']['USD']
           
                # person = input('Enter your name: ')
        
                # Load rates
                memoryelement=itemAttributes['memory']
                memory=re.sub('[^0-9]','', memoryelement)
                dfInstanceList.loc[index, 'instanceType'] = itemAttributes['instanceType']
                dfInstanceList.loc[index, 'memory'] =  memory
                dfInstanceList.loc[index,'family'] = family
                dfInstanceList.loc[index, 'vcpu'] = vcpu 
                dfInstanceList.loc[index, 'one_hr_rate'] = onehr_rate
                dfInstanceList.loc[index, 'one_yr_rate'] = oneyr_rate
                dfInstanceList.loc[index, 'three_yr_rate'] = threeyr_rate
                index=index+1
            
            #Convert memory to numeric
            
            dfInstanceList['memory']=dfInstanceList['memory'].apply(pd.to_numeric)
            dfInstanceList['vcpu']=dfInstanceList['vcpu'].apply(pd.to_numeric)
            dfInstanceList['one_hr_rate']=dfInstanceList['one_hr_rate'].apply(pd.to_numeric)
            dfInstanceList['one_yr_rate']=dfInstanceList['one_yr_rate'].apply(pd.to_numeric)
            dfInstanceList['three_yr_rate']=dfInstanceList['three_yr_rate'].apply(pd.to_numeric)

            dfInstanceList_sorted=dfInstanceList.sort_values(by=['vcpu'], ascending=True)
            dfInstanceList_sorted=dfInstanceList_sorted.reset_index(drop=True)
            
            #if region == "ap-northeast-2":
            #    myregion = "ap-southeast-1"
            #else: myregion = region
            
            myregion=region
                    
            dfCMDB_filter = dfCMDB[(dfCMDB.calc_family == family) & (dfCMDB.AWS_DB == db) & (dfCMDB.RDS == True) & (dfCMDB.AWS_Region == myregion)]

            
            # Map instances to EC2 instance types  
            for index in dfCMDB_filter.index.tolist():
                found=False
                instance=0
                
                while ((not(found)) & (instance < len(dfInstanceList_sorted))):
                    if ((dfInstanceList_sorted.loc[instance, 'memory'] >= dfCMDB.loc[index, 'Peak Mem Used']) and (dfInstanceList_sorted.loc[instance, 'vcpu'] >= dfCMDB.loc[index, 'cores_calc'])):
                        found = True
                        dfCMDB.loc[index, 'ec2_instance_type'] = dfInstanceList_sorted.loc[instance, 'instanceType']
                        dfCMDB.loc[index, 'one_hr_rate'] = dfInstanceList_sorted.loc[instance, 'one_hr_rate']
                        dfCMDB.loc[index, 'one_yr_rate'] = dfInstanceList_sorted.loc[instance, 'one_yr_rate']
                        dfCMDB.loc[index, 'three_yr_rate'] = dfInstanceList_sorted.loc[instance, 'three_yr_rate']

                    instance = instance +1
                    
# Compute EBS and snapshots
dfCMDB['ebs_month_rate'] = 0
print('Pricing EBS and snapshots...')

# Flat storage rates assuming 1% monthly rate of change on EC2

for index in dfCMDB.index.tolist():
    if dfCMDB.loc[index, 'RDS'] == True:
        dfCMDB.loc[index, 'ebs_month_rate'] = dfCMDB.loc[index, srcBlockStorage] * rdsEBSUnitCost
    else:
        dfCMDB.loc[index, 'ebs_month_rate'] = dfCMDB.loc[index, srcBlockStorage] * ec2EBSUnitCost

# Write output file
print("Writing output file...")
dfCMDB.to_csv(fileOutput)
# Out:
# Reading input file....
# Determining RDS targets....
# Calculating target EC2 cores...
# Determining EC2 instance families...
# Mapping regions...
# Determining OS platforms...
# Pricing EC2 instances....
# Region us-east-1
# OS RHEL
# Family t
# Family m
# Family c
# Family r
# OS Linux
# Family t
# Family m
# Family c
# Family r
# OS Windows
# Family t
# Family m
# Family c
# Family r
# Region ap-northeast-2
# OS RHEL
# Family t
# Family m
# Family c
# Family r
# OS Linux
# Family t
# Family m
# Family c
# Family r
# OS Windows
# Family t
# Family m
# Family c
# Family r
# Region eu-central-1
# OS RHEL
# Family t
# Family m
# Family c
# Family r
# OS Linux
# Family t
# Family m
# Family c
# Family r
# OS Windows
# Family t
# Family m
# Family c
# Family r
# Pricing RDS...
# Region us-east-1
# DB Oracle
# Family t
# Family m
# Family c
# Family r
# DB SQL Server
# Family t
# Family m
# Family c
# Family r
# DB Aurora MySQL
# Family t
# Family m
# Family c
# Family r
# Region ap-northeast-2
# DB Oracle
# Family t
# Family m
# Family c
# Family r
# DB SQL Server
# Family t
# Family m
# Family c
# Family r
# DB Aurora MySQL
# Family t
# Family m
# Family c
# Family r
# Region eu-central-1
# DB Oracle
# Family t
# Family m
# Family c
# Family r
# DB SQL Server
# Family t
# Family m
# Family c
# Family r
# DB Aurora MySQL
# Family t
# Family m
# Family c
# Family r
# Pricing EBS and snapshots...
# Writing output file...

# %%
jItem
# Out:
# {'product': {'attributes': {'capacitystatus': 'None',
#    'clockSpeed': '2.5 GHz',
#    'currentGeneration': 'Yes',
#    'dedicatedEbsThroughput': '6000 Mbps',
#    'ecu': '173',
#    'enhancedNetworkingSupported': 'Yes',
#    'instanceFamily': 'General purpose',
#    'instanceType': 'm5d.12xlarge',
#    'licenseModel': 'No License required',
#    'location': 'US East (N. Virginia)',
#    'locationType': 'AWS Region',
#    'memory': '192 GiB',
#    'networkPerformance': '10 Gigabit',
#    'normalizationSizeFactor': '96',
#    'operatingSystem': 'RHEL',
#    'operation': 'RunInstances:0010',
#    'physicalProcessor': 'Intel Xeon Platinum 8175',
#    'preInstalledSw': 'NA',
#    'processorArchitecture': '64-bit',
#    'processorFeatures': 'Intel AVX, Intel AVX2, Intel AVX512, Intel Turbo',
#    'servicecode': 'AmazonEC2',
#    'servicename': 'Amazon Elastic Compute Cloud',
#    'storage': '2 x 900',
#    'tenancy': 'Shared',
#    'usagetype': 'BoxUsage:m5d.12xlarge',
#    'vcpu': '48'},
#   'productFamily': 'Compute Instance',
#   'sku': '2KETVFF4RS3K6SVY'},
#  'publicationDate': '2018-06-04T19:23:35Z',
#  'serviceCode': 'AmazonEC2',
#  'terms': {'OnDemand': {'2KETVFF4RS3K6SVY.JRTCKXETXF': {'effectiveDate': '2018-05-01T00:00:00Z',
#     'offerTermCode': 'JRTCKXETXF',
#     'priceDimensions': {'2KETVFF4RS3K6SVY.JRTCKXETXF.6YS6EN2CT7': {'appliesTo': [],
#       'beginRange': '0',
#       'description': '$2.842 per On Demand RHEL m5d.12xlarge Instance Hour',
#       'endRange': 'Inf',
#       'pricePerUnit': {'USD': '2.8420000000'},
#       'rateCode': '2KETVFF4RS3K6SVY.JRTCKXETXF.6YS6EN2CT7',
#       'unit': 'Hrs'}},
#     'sku': '2KETVFF4RS3K6SVY',
#     'termAttributes': {}}},
#   'Reserved': {'2KETVFF4RS3K6SVY.38NPMPTW36': {'effectiveDate': '2018-05-31T23:59:59Z',
#     'offerTermCode': '38NPMPTW36',
#     'priceDimensions': {'2KETVFF4RS3K6SVY.38NPMPTW36.2TG2D8R56U': {'appliesTo': [],
#       'description': 'Upfront Fee',
#       'pricePerUnit': {'USD': '14441'},
#       'rateCode': '2KETVFF4RS3K6SVY.38NPMPTW36.2TG2D8R56U',
#       'unit': 'Quantity'},
#      '2KETVFF4RS3K6SVY.38NPMPTW36.6YS6EN2CT7': {'appliesTo': [],
#       'beginRange': '0',
#       'description': 'Red Hat Enterprise Linux (Amazon VPC), m5d.12xlarge reserved instance applied',
#       'endRange': 'Inf',
#       'pricePerUnit': {'USD': '0.6790000000'},
#       'rateCode': '2KETVFF4RS3K6SVY.38NPMPTW36.6YS6EN2CT7',
#       'unit': 'Hrs'}},
#     'sku': '2KETVFF4RS3K6SVY',
#     'termAttributes': {'LeaseContractLength': '3yr',
#      'OfferingClass': 'standard',
#      'PurchaseOption': 'Partial Upfront'}},
#    '2KETVFF4RS3K6SVY.7NE97W5U4E': {'effectiveDate': '2018-05-31T23:59:59Z',
#     'offerTermCode': '7NE97W5U4E',
#     'priceDimensions': {'2KETVFF4RS3K6SVY.7NE97W5U4E.6YS6EN2CT7': {'appliesTo': [],
#       'beginRange': '0',
#       'description': 'Red Hat Enterprise Linux (Amazon VPC), m5d.12xlarge reserved instance applied',
#       'endRange': 'Inf',
#       'pricePerUnit': {'USD': '2.1160000000'},
#       'rateCode': '2KETVFF4RS3K6SVY.7NE97W5U4E.6YS6EN2CT7',
#       'unit': 'Hrs'}},
#     'sku': '2KETVFF4RS3K6SVY',
#     'termAttributes': {'LeaseContractLength': '1yr',
#      'OfferingClass': 'convertible',
#      'PurchaseOption': 'No Upfront'}},
#    '2KETVFF4RS3K6SVY.BPH4J8HBKS': {'effectiveDate': '2018-05-31T23:59:59Z',
#     'offerTermCode': 'BPH4J8HBKS',
#     'priceDimensions': {'2KETVFF4RS3K6SVY.BPH4J8HBKS.6YS6EN2CT7': {'appliesTo': [],
#       'beginRange': '0',
#       'description': 'Red Hat Enterprise Linux (Amazon VPC), m5d.12xlarge reserved instance applied',
#       'endRange': 'Inf',
#       'pricePerUnit': {'USD': '1.3170000000'},
#       'rateCode': '2KETVFF4RS3K6SVY.BPH4J8HBKS.6YS6EN2CT7',
#       'unit': 'Hrs'}},
#     'sku': '2KETVFF4RS3K6SVY',
#     'termAttributes': {'LeaseContractLength': '3yr',
#      'OfferingClass': 'standard',
#      'PurchaseOption': 'No Upfront'}},
#    '2KETVFF4RS3K6SVY.CUZHX8X6JH': {'effectiveDate': '2018-05-31T23:59:59Z',
#     'offerTermCode': 'CUZHX8X6JH',
#     'priceDimensions': {'2KETVFF4RS3K6SVY.CUZHX8X6JH.2TG2D8R56U': {'appliesTo': [],
#       'description': 'Upfront Fee',
#       'pricePerUnit': {'USD': '8284'},
#       'rateCode': '2KETVFF4RS3K6SVY.CUZHX8X6JH.2TG2D8R56U',
#       'unit': 'Quantity'},
#      '2KETVFF4RS3K6SVY.CUZHX8X6JH.6YS6EN2CT7': {'appliesTo': [],
#       'beginRange': '0',
#       'description': 'Red Hat Enterprise Linux (Amazon VPC), m5d.12xlarge reserved instance applied',
#       'endRange': 'Inf',
#       'pricePerUnit': {'USD': '1.0760000000'},
#       'rateCode': '2KETVFF4RS3K6SVY.CUZHX8X6JH.6YS6EN2CT7',
#       'unit': 'Hrs'}},
#     'sku': '2KETVFF4RS3K6SVY',
#     'termAttributes': {'LeaseContractLength': '1yr',
#      'OfferingClass': 'convertible',
#      'PurchaseOption': 'Partial Upfront'}},
#    '2KETVFF4RS3K6SVY.MZU6U2429S': {'effectiveDate': '2018-05-31T23:59:59Z',
#     'offerTermCode': 'MZU6U2429S',
#     'priceDimensions': {'2KETVFF4RS3K6SVY.MZU6U2429S.2TG2D8R56U': {'appliesTo': [],
#       'description': 'Upfront Fee',
#       'pricePerUnit': {'USD': '35966'},
#       'rateCode': '2KETVFF4RS3K6SVY.MZU6U2429S.2TG2D8R56U',
#       'unit': 'Quantity'},
#      '2KETVFF4RS3K6SVY.MZU6U2429S.6YS6EN2CT7': {'appliesTo': [],
#       'beginRange': '0',
#       'description': 'Red Hat Enterprise Linux (Amazon VPC), m5d.12xlarge reserved instance applied',
#       'endRange': 'Inf',
#       'pricePerUnit': {'USD': '0.0000000000'},
#       'rateCode': '2KETVFF4RS3K6SVY.MZU6U2429S.6YS6EN2CT7',
#       'unit': 'Hrs'}},
#     'sku': '2KETVFF4RS3K6SVY',
#     'termAttributes': {'LeaseContractLength': '3yr',
#      'OfferingClass': 'convertible',
#      'PurchaseOption': 'All Upfront'}},
#    '2KETVFF4RS3K6SVY.NQ3QZPMQV9': {'effectiveDate': '2018-05-31T23:59:59Z',
#     'offerTermCode': 'NQ3QZPMQV9',
#     'priceDimensions': {'2KETVFF4RS3K6SVY.NQ3QZPMQV9.2TG2D8R56U': {'appliesTo': [],
#       'description': 'Upfront Fee',
#       'pricePerUnit': {'USD': '30565'},
#       'rateCode': '2KETVFF4RS3K6SVY.NQ3QZPMQV9.2TG2D8R56U',
#       'unit': 'Quantity'},
#      '2KETVFF4RS3K6SVY.NQ3QZPMQV9.6YS6EN2CT7': {'appliesTo': [],
#       'beginRange': '0',
#       'description': 'Red Hat Enterprise Linux (Amazon VPC), m5d.12xlarge reserved instance applied',
#       'endRange': 'Inf',
#       'pricePerUnit': {'USD': '0.0000000000'},
#       'rateCode': '2KETVFF4RS3K6SVY.NQ3QZPMQV9.6YS6EN2CT7',
#       'unit': 'Hrs'}},
#     'sku': '2KETVFF4RS3K6SVY',
#     'termAttributes': {'LeaseContractLength': '3yr',
#      'OfferingClass': 'standard',
#      'PurchaseOption': 'All Upfront'}},
#    '2KETVFF4RS3K6SVY.R5XV2EPZQZ': {'effectiveDate': '2018-05-31T23:59:59Z',
#     'offerTermCode': 'R5XV2EPZQZ',
#     'priceDimensions': {'2KETVFF4RS3K6SVY.R5XV2EPZQZ.2TG2D8R56U': {'appliesTo': [],
#       'description': 'Upfront Fee',
#       'pricePerUnit': {'USD': '16607'},
#       'rateCode': '2KETVFF4RS3K6SVY.R5XV2EPZQZ.2TG2D8R56U',
#       'unit': 'Quantity'},
#      '2KETVFF4RS3K6SVY.R5XV2EPZQZ.6YS6EN2CT7': {'appliesTo': [],
#       'beginRange': '0',
#       'description': 'Red Hat Enterprise Linux (Amazon VPC), m5d.12xlarge reserved instance applied',
#       'endRange': 'Inf',
#       'pricePerUnit': {'USD': '0.7620000000'},
#       'rateCode': '2KETVFF4RS3K6SVY.R5XV2EPZQZ.6YS6EN2CT7',
#       'unit': 'Hrs'}},
#     'sku': '2KETVFF4RS3K6SVY',
#     'termAttributes': {'LeaseContractLength': '3yr',
#      'OfferingClass': 'convertible',
#      'PurchaseOption': 'Partial Upfront'}},
#    '2KETVFF4RS3K6SVY.VJWZNREJX2': {'effectiveDate': '2018-05-31T23:59:59Z',
#     'offerTermCode': 'VJWZNREJX2',
#     'priceDimensions': {'2KETVFF4RS3K6SVY.VJWZNREJX2.2TG2D8R56U': {'appliesTo': [],
#       'description': 'Upfront Fee',
#       'pricePerUnit': {'USD': '17376'},
#       'rateCode': '2KETVFF4RS3K6SVY.VJWZNREJX2.2TG2D8R56U',
#       'unit': 'Quantity'},
#      '2KETVFF4RS3K6SVY.VJWZNREJX2.6YS6EN2CT7': {'appliesTo': [],
#       'beginRange': '0',
#       'description': 'Red Hat Enterprise Linux (Amazon VPC), m5d.12xlarge reserved instance applied',
#       'endRange': 'Inf',
#       'pricePerUnit': {'USD': '0.0000000000'},
#       'rateCode': '2KETVFF4RS3K6SVY.VJWZNREJX2.6YS6EN2CT7',
#       'unit': 'Hrs'}},
#     'sku': '2KETVFF4RS3K6SVY',
#     'termAttributes': {'LeaseContractLength': '1yr',
#      'OfferingClass': 'convertible',
#      'PurchaseOption': 'All Upfront'}},
#    '2KETVFF4RS3K6SVY.Z2E3P23VKM': {'effectiveDate': '2018-05-31T23:59:59Z',
#     'offerTermCode': 'Z2E3P23VKM',
#     'priceDimensions': {'2KETVFF4RS3K6SVY.Z2E3P23VKM.6YS6EN2CT7': {'appliesTo': [],
#       'beginRange': '0',
#       'description': 'Red Hat Enterprise Linux (Amazon VPC), m5d.12xlarge reserved instance applied',
#       'endRange': 'Inf',
#       'pricePerUnit': {'USD': '1.4950000000'},
#       'rateCode': '2KETVFF4RS3K6SVY.Z2E3P23VKM.6YS6EN2CT7',
#       'unit': 'Hrs'}},
#     'sku': '2KETVFF4RS3K6SVY',
#     'termAttributes': {'LeaseContractLength': '3yr',
#      'OfferingClass': 'convertible',
#      'PurchaseOption': 'No Upfront'}}}},
#  'version': '20180604192335'}

# %%
instancefamily
# Out:
# 'm5'

# %%
families
# Out:
# {'c', 'm', 'r', 't'}

# %%
os
# Out:
# 'RHEL'

# %%
region
# Out:
# 'us-east-1'

# %%
instancefamily
# Out:
# 'm5'

# %%
items
# Out:
# ['{"product":{"productFamily":"Compute Instance","attributes":{"enhancedNetworkingSupported":"Yes","memory":"192 GiB","dedicatedEbsThroughput":"6000 Mbps","vcpu":"48","capacitystatus":"None","locationType":"AWS Region","storage":"2 x 900","instanceFamily":"General purpose","operatingSystem":"RHEL","physicalProcessor":"Intel Xeon Platinum 8175","clockSpeed":"2.5 GHz","ecu":"173","networkPerformance":"10 Gigabit","servicename":"Amazon Elastic Compute Cloud","instanceType":"m5d.12xlarge","tenancy":"Shared","usagetype":"BoxUsage:m5d.12xlarge","normalizationSizeFactor":"96","processorFeatures":"Intel AVX, Intel AVX2, Intel AVX512, Intel Turbo","servicecode":"AmazonEC2","licenseModel":"No License required","currentGeneration":"Yes","preInstalledSw":"NA","location":"US East (N. Virginia)","processorArchitecture":"64-bit","operation":"RunInstances:0010"},"sku":"2KETVFF4RS3K6SVY"},"serviceCode":"AmazonEC2","terms":{"OnDemand":{"2KETVFF4RS3K6SVY.JRTCKXETXF":{"priceDimensions":{"2KETVFF4RS3K6SVY.JRTCKXETXF.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"$2.842 per On Demand RHEL m5d.12xlarge Instance Hour","appliesTo":[],"rateCode":"2KETVFF4RS3K6SVY.JRTCKXETXF.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"2.8420000000"}}},"sku":"2KETVFF4RS3K6SVY","effectiveDate":"2018-05-01T00:00:00Z","offerTermCode":"JRTCKXETXF","termAttributes":{}}},"Reserved":{"2KETVFF4RS3K6SVY.7NE97W5U4E":{"priceDimensions":{"2KETVFF4RS3K6SVY.7NE97W5U4E.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5d.12xlarge reserved instance applied","appliesTo":[],"rateCode":"2KETVFF4RS3K6SVY.7NE97W5U4E.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"2.1160000000"}}},"sku":"2KETVFF4RS3K6SVY","effectiveDate":"2018-05-31T23:59:59Z","offerTermCode":"7NE97W5U4E","termAttributes":{"LeaseContractLength":"1yr","OfferingClass":"convertible","PurchaseOption":"No Upfront"}},"2KETVFF4RS3K6SVY.MZU6U2429S":{"priceDimensions":{"2KETVFF4RS3K6SVY.MZU6U2429S.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"2KETVFF4RS3K6SVY.MZU6U2429S.2TG2D8R56U","pricePerUnit":{"USD":"35966"}},"2KETVFF4RS3K6SVY.MZU6U2429S.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5d.12xlarge reserved instance applied","appliesTo":[],"rateCode":"2KETVFF4RS3K6SVY.MZU6U2429S.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.0000000000"}}},"sku":"2KETVFF4RS3K6SVY","effectiveDate":"2018-05-31T23:59:59Z","offerTermCode":"MZU6U2429S","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"convertible","PurchaseOption":"All Upfront"}},"2KETVFF4RS3K6SVY.BPH4J8HBKS":{"priceDimensions":{"2KETVFF4RS3K6SVY.BPH4J8HBKS.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5d.12xlarge reserved instance applied","appliesTo":[],"rateCode":"2KETVFF4RS3K6SVY.BPH4J8HBKS.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"1.3170000000"}}},"sku":"2KETVFF4RS3K6SVY","effectiveDate":"2018-05-31T23:59:59Z","offerTermCode":"BPH4J8HBKS","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"standard","PurchaseOption":"No Upfront"}},"2KETVFF4RS3K6SVY.CUZHX8X6JH":{"priceDimensions":{"2KETVFF4RS3K6SVY.CUZHX8X6JH.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"2KETVFF4RS3K6SVY.CUZHX8X6JH.2TG2D8R56U","pricePerUnit":{"USD":"8284"}},"2KETVFF4RS3K6SVY.CUZHX8X6JH.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5d.12xlarge reserved instance applied","appliesTo":[],"rateCode":"2KETVFF4RS3K6SVY.CUZHX8X6JH.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"1.0760000000"}}},"sku":"2KETVFF4RS3K6SVY","effectiveDate":"2018-05-31T23:59:59Z","offerTermCode":"CUZHX8X6JH","termAttributes":{"LeaseContractLength":"1yr","OfferingClass":"convertible","PurchaseOption":"Partial Upfront"}},"2KETVFF4RS3K6SVY.VJWZNREJX2":{"priceDimensions":{"2KETVFF4RS3K6SVY.VJWZNREJX2.2TG2D8R ...
#  '{"product":{"productFamily":"Compute Instance","attributes":{"enhancedNetworkingSupported":"Yes","memory":"64 GiB","dedicatedEbsThroughput":"2120 Mbps","vcpu":"16","capacitystatus":"Used","locationType":"AWS Region","storage":"EBS only","instanceFamily":"General purpose","operatingSystem":"RHEL","physicalProcessor":"Intel Xeon Platinum 8175","clockSpeed":"2.5 GHz","ecu":"61","networkPerformance":"Up to 10 Gigabit","servicename":"Amazon Elastic Compute Cloud","instanceType":"m5.4xlarge","tenancy":"Shared","usagetype":"BoxUsage:m5.4xlarge","normalizationSizeFactor":"32","processorFeatures":"Intel AVX, Intel AVX2, Intel AVX512, Intel Turbo","servicecode":"AmazonEC2","licenseModel":"No License required","currentGeneration":"Yes","preInstalledSw":"NA","location":"US East (N. Virginia)","processorArchitecture":"64-bit","operation":"RunInstances:0010"},"sku":"3PFRBSXSD3ASHUXZ"},"serviceCode":"AmazonEC2","terms":{"OnDemand":{"3PFRBSXSD3ASHUXZ.JRTCKXETXF":{"priceDimensions":{"3PFRBSXSD3ASHUXZ.JRTCKXETXF.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"$0.898 per On Demand RHEL m5.4xlarge Instance Hour","appliesTo":[],"rateCode":"3PFRBSXSD3ASHUXZ.JRTCKXETXF.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.8980000000"}}},"sku":"3PFRBSXSD3ASHUXZ","effectiveDate":"2018-05-01T00:00:00Z","offerTermCode":"JRTCKXETXF","termAttributes":{}}},"Reserved":{"3PFRBSXSD3ASHUXZ.HU7G6KETJZ":{"priceDimensions":{"3PFRBSXSD3ASHUXZ.HU7G6KETJZ.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"3PFRBSXSD3ASHUXZ.HU7G6KETJZ.2TG2D8R56U","pricePerUnit":{"USD":"2047"}},"3PFRBSXSD3ASHUXZ.HU7G6KETJZ.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5.4xlarge reserved instance applied","appliesTo":[],"rateCode":"3PFRBSXSD3ASHUXZ.HU7G6KETJZ.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.3640000000"}}},"sku":"3PFRBSXSD3ASHUXZ","effectiveDate":"2017-12-31T23:59:59Z","offerTermCode":"HU7G6KETJZ","termAttributes":{"LeaseContractLength":"1yr","OfferingClass":"standard","PurchaseOption":"Partial Upfront"}},"3PFRBSXSD3ASHUXZ.NQ3QZPMQV9":{"priceDimensions":{"3PFRBSXSD3ASHUXZ.NQ3QZPMQV9.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"3PFRBSXSD3ASHUXZ.NQ3QZPMQV9.2TG2D8R56U","pricePerUnit":{"USD":"11163"}},"3PFRBSXSD3ASHUXZ.NQ3QZPMQV9.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5.4xlarge reserved instance applied","appliesTo":[],"rateCode":"3PFRBSXSD3ASHUXZ.NQ3QZPMQV9.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.0000000000"}}},"sku":"3PFRBSXSD3ASHUXZ","effectiveDate":"2017-12-31T23:59:59Z","offerTermCode":"NQ3QZPMQV9","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"standard","PurchaseOption":"All Upfront"}},"3PFRBSXSD3ASHUXZ.Z2E3P23VKM":{"priceDimensions":{"3PFRBSXSD3ASHUXZ.Z2E3P23VKM.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5.4xlarge reserved instance applied","appliesTo":[],"rateCode":"3PFRBSXSD3ASHUXZ.Z2E3P23VKM.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.5190000000"}}},"sku":"3PFRBSXSD3ASHUXZ","effectiveDate":"2017-10-31T23:59:59Z","offerTermCode":"Z2E3P23VKM","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"convertible","PurchaseOption":"No Upfront"}},"3PFRBSXSD3ASHUXZ.6QCMYABX3D":{"priceDimensions":{"3PFRBSXSD3ASHUXZ.6QCMYABX3D.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5.4xlarge reserved instance applied","appliesTo":[],"rateCode":"3PFRBSXSD3ASHUXZ.6QCMYABX3D.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.0000000000"}},"3PFRBSXSD3ASHUXZ.6QCMYABX3D.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"3PFRBSXSD3ASHUXZ.6QCMYABX3D.2TG2D8R56U","pricePerUnit":{"USD":"5150"}}},"sku":"3PFRBSXSD3ASHUXZ","effectiveDate":"2017-12-31T23:59:59Z","offerTermCode":"6QCMYABX3D","termAttributes":{"L ...
#  '{"product":{"productFamily":"Compute Instance","attributes":{"enhancedNetworkingSupported":"Yes","memory":"8 GiB","dedicatedEbsThroughput":"Upto 2120 Mbps","vcpu":"2","capacitystatus":"None","locationType":"AWS Region","storage":"1 x 75","instanceFamily":"General purpose","operatingSystem":"RHEL","physicalProcessor":"Intel Xeon Platinum 8175","clockSpeed":"2.5 GHz","ecu":"10","networkPerformance":"Up to 10 Gigabit","servicename":"Amazon Elastic Compute Cloud","instanceType":"m5d.large","tenancy":"Shared","usagetype":"BoxUsage:m5d.large","normalizationSizeFactor":"4","processorFeatures":"Intel AVX, Intel AVX2, Intel AVX512, Intel Turbo","servicecode":"AmazonEC2","licenseModel":"No License required","currentGeneration":"Yes","preInstalledSw":"NA","location":"US East (N. Virginia)","processorArchitecture":"64-bit","operation":"RunInstances:0010"},"sku":"5QU8BFJFD9XC3M9R"},"serviceCode":"AmazonEC2","terms":{"OnDemand":{"5QU8BFJFD9XC3M9R.JRTCKXETXF":{"priceDimensions":{"5QU8BFJFD9XC3M9R.JRTCKXETXF.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"$0.173 per On Demand RHEL m5d.large Instance Hour","appliesTo":[],"rateCode":"5QU8BFJFD9XC3M9R.JRTCKXETXF.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.1730000000"}}},"sku":"5QU8BFJFD9XC3M9R","effectiveDate":"2018-05-01T00:00:00Z","offerTermCode":"JRTCKXETXF","termAttributes":{}}},"Reserved":{"5QU8BFJFD9XC3M9R.CUZHX8X6JH":{"priceDimensions":{"5QU8BFJFD9XC3M9R.CUZHX8X6JH.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"5QU8BFJFD9XC3M9R.CUZHX8X6JH.2TG2D8R56U","pricePerUnit":{"USD":"345"}},"5QU8BFJFD9XC3M9R.CUZHX8X6JH.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5d.large reserved instance applied","appliesTo":[],"rateCode":"5QU8BFJFD9XC3M9R.CUZHX8X6JH.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.0990000000"}}},"sku":"5QU8BFJFD9XC3M9R","effectiveDate":"2018-05-31T23:59:59Z","offerTermCode":"CUZHX8X6JH","termAttributes":{"LeaseContractLength":"1yr","OfferingClass":"convertible","PurchaseOption":"Partial Upfront"}},"5QU8BFJFD9XC3M9R.4NA7Y494T4":{"priceDimensions":{"5QU8BFJFD9XC3M9R.4NA7Y494T4.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5d.large reserved instance applied","appliesTo":[],"rateCode":"5QU8BFJFD9XC3M9R.4NA7Y494T4.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.1320000000"}}},"sku":"5QU8BFJFD9XC3M9R","effectiveDate":"2018-05-31T23:59:59Z","offerTermCode":"4NA7Y494T4","termAttributes":{"LeaseContractLength":"1yr","OfferingClass":"standard","PurchaseOption":"No Upfront"}},"5QU8BFJFD9XC3M9R.6QCMYABX3D":{"priceDimensions":{"5QU8BFJFD9XC3M9R.6QCMYABX3D.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"5QU8BFJFD9XC3M9R.6QCMYABX3D.2TG2D8R56U","pricePerUnit":{"USD":"1114"}},"5QU8BFJFD9XC3M9R.6QCMYABX3D.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5d.large reserved instance applied","appliesTo":[],"rateCode":"5QU8BFJFD9XC3M9R.6QCMYABX3D.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.0000000000"}}},"sku":"5QU8BFJFD9XC3M9R","effectiveDate":"2018-05-31T23:59:59Z","offerTermCode":"6QCMYABX3D","termAttributes":{"LeaseContractLength":"1yr","OfferingClass":"standard","PurchaseOption":"All Upfront"}},"5QU8BFJFD9XC3M9R.R5XV2EPZQZ":{"priceDimensions":{"5QU8BFJFD9XC3M9R.R5XV2EPZQZ.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"5QU8BFJFD9XC3M9R.R5XV2EPZQZ.2TG2D8R56U","pricePerUnit":{"USD":"692"}},"5QU8BFJFD9XC3M9R.R5XV2EPZQZ.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5d.large reserved instance applied","appliesTo":[],"rateCode":"5QU8BFJFD9XC3M9R.R5XV2EPZQZ.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.0860000000"}}},"sku":"5QU8BFJFD9XC3M9R","effectiveDate":"2018-05-31T23:59:59Z","offerTermCode":"R5XV2EPZQZ","termAttributes":{"LeaseContra ...
#  '{"product":{"productFamily":"Compute Instance","attributes":{"enhancedNetworkingSupported":"Yes","memory":"8 GiB","dedicatedEbsThroughput":"450 Mbps","vcpu":"2","capacitystatus":"Used","locationType":"AWS Region","storage":"EBS only","instanceFamily":"General purpose","operatingSystem":"RHEL","physicalProcessor":"Intel Xeon E5-2676 v3 (Haswell)","clockSpeed":"2.4 GHz","ecu":"6.5","networkPerformance":"Moderate","servicename":"Amazon Elastic Compute Cloud","instanceType":"m4.large","tenancy":"Shared","usagetype":"BoxUsage:m4.large","normalizationSizeFactor":"4","processorFeatures":"Intel AVX; Intel AVX2; Intel Turbo","servicecode":"AmazonEC2","licenseModel":"No License required","currentGeneration":"Yes","preInstalledSw":"NA","location":"US East (N. Virginia)","processorArchitecture":"64-bit","operation":"RunInstances:0010"},"sku":"6555VGRWG4AP5HWV"},"serviceCode":"AmazonEC2","terms":{"OnDemand":{"6555VGRWG4AP5HWV.JRTCKXETXF":{"priceDimensions":{"6555VGRWG4AP5HWV.JRTCKXETXF.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"$0.16 per On Demand RHEL m4.large Instance Hour","appliesTo":[],"rateCode":"6555VGRWG4AP5HWV.JRTCKXETXF.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.1600000000"}}},"sku":"6555VGRWG4AP5HWV","effectiveDate":"2018-05-01T00:00:00Z","offerTermCode":"JRTCKXETXF","termAttributes":{}}},"Reserved":{"6555VGRWG4AP5HWV.R5XV2EPZQZ":{"priceDimensions":{"6555VGRWG4AP5HWV.R5XV2EPZQZ.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"6555VGRWG4AP5HWV.R5XV2EPZQZ.2TG2D8R56U","pricePerUnit":{"USD":"604"}},"6555VGRWG4AP5HWV.R5XV2EPZQZ.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m4.large reserved instance applied","appliesTo":[],"rateCode":"6555VGRWG4AP5HWV.R5XV2EPZQZ.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.0830000000"}}},"sku":"6555VGRWG4AP5HWV","effectiveDate":"2017-04-30T23:59:59Z","offerTermCode":"R5XV2EPZQZ","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"convertible","PurchaseOption":"Partial Upfront"}},"6555VGRWG4AP5HWV.NQ3QZPMQV9":{"priceDimensions":{"6555VGRWG4AP5HWV.NQ3QZPMQV9.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"6555VGRWG4AP5HWV.NQ3QZPMQV9.2TG2D8R56U","pricePerUnit":{"USD":"2565"}},"6555VGRWG4AP5HWV.NQ3QZPMQV9.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m4.large reserved instance applied","appliesTo":[],"rateCode":"6555VGRWG4AP5HWV.NQ3QZPMQV9.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.0000000000"}}},"sku":"6555VGRWG4AP5HWV","effectiveDate":"2017-04-30T23:59:59Z","offerTermCode":"NQ3QZPMQV9","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"standard","PurchaseOption":"All Upfront"}},"6555VGRWG4AP5HWV.Z2E3P23VKM":{"priceDimensions":{"6555VGRWG4AP5HWV.Z2E3P23VKM.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m4.large reserved instance applied","appliesTo":[],"rateCode":"6555VGRWG4AP5HWV.Z2E3P23VKM.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.1097000000"}}},"sku":"6555VGRWG4AP5HWV","effectiveDate":"2017-04-30T23:59:59Z","offerTermCode":"Z2E3P23VKM","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"convertible","PurchaseOption":"No Upfront"}},"6555VGRWG4AP5HWV.BPH4J8HBKS":{"priceDimensions":{"6555VGRWG4AP5HWV.BPH4J8HBKS.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m4.large reserved instance applied","appliesTo":[],"rateCode":"6555VGRWG4AP5HWV.BPH4J8HBKS.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.1032000000"}}},"sku":"6555VGRWG4AP5HWV","effectiveDate":"2017-04-30T23:59:59Z","offerTermCode":"BPH4J8HBKS","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"standard","PurchaseOption":"No Upfront"}},"6555VGRWG4AP5HWV.38NPMPTW36":{"priceDimensions":{"6555VGRWG4AP5HWV.38NPMPTW36.2TG2D8R56U":{"unit":"Quantity","description":"Upfront  ...
#  '{"product":{"productFamily":"Compute Instance","attributes":{"enhancedNetworkingSupported":"Yes","memory":"32 GiB","dedicatedEbsThroughput":"Upto 2120 Mbps","vcpu":"8","capacitystatus":"None","locationType":"AWS Region","storage":"1 x 300","instanceFamily":"General purpose","operatingSystem":"RHEL","physicalProcessor":"Intel Xeon Platinum 8175","clockSpeed":"2.5 GHz","ecu":"31","networkPerformance":"Up to 10 Gigabit","servicename":"Amazon Elastic Compute Cloud","instanceType":"m5d.2xlarge","tenancy":"Shared","usagetype":"BoxUsage:m5d.2xlarge","normalizationSizeFactor":"16","processorFeatures":"Intel AVX, Intel AVX2, Intel AVX512, Intel Turbo","servicecode":"AmazonEC2","licenseModel":"No License required","currentGeneration":"Yes","preInstalledSw":"NA","location":"US East (N. Virginia)","processorArchitecture":"64-bit","operation":"RunInstances:0010"},"sku":"86TNYEJNEPKUUMBJ"},"serviceCode":"AmazonEC2","terms":{"OnDemand":{"86TNYEJNEPKUUMBJ.JRTCKXETXF":{"priceDimensions":{"86TNYEJNEPKUUMBJ.JRTCKXETXF.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"$0.582 per On Demand RHEL m5d.2xlarge Instance Hour","appliesTo":[],"rateCode":"86TNYEJNEPKUUMBJ.JRTCKXETXF.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.5820000000"}}},"sku":"86TNYEJNEPKUUMBJ","effectiveDate":"2018-05-01T00:00:00Z","offerTermCode":"JRTCKXETXF","termAttributes":{}}},"Reserved":{"86TNYEJNEPKUUMBJ.38NPMPTW36":{"priceDimensions":{"86TNYEJNEPKUUMBJ.38NPMPTW36.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5d.2xlarge reserved instance applied","appliesTo":[],"rateCode":"86TNYEJNEPKUUMBJ.38NPMPTW36.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.2220000000"}},"86TNYEJNEPKUUMBJ.38NPMPTW36.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"86TNYEJNEPKUUMBJ.38NPMPTW36.2TG2D8R56U","pricePerUnit":{"USD":"2407"}}},"sku":"86TNYEJNEPKUUMBJ","effectiveDate":"2018-05-31T23:59:59Z","offerTermCode":"38NPMPTW36","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"standard","PurchaseOption":"Partial Upfront"}},"86TNYEJNEPKUUMBJ.MZU6U2429S":{"priceDimensions":{"86TNYEJNEPKUUMBJ.MZU6U2429S.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"86TNYEJNEPKUUMBJ.MZU6U2429S.2TG2D8R56U","pricePerUnit":{"USD":"8841"}},"86TNYEJNEPKUUMBJ.MZU6U2429S.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5d.2xlarge reserved instance applied","appliesTo":[],"rateCode":"86TNYEJNEPKUUMBJ.MZU6U2429S.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.0000000000"}}},"sku":"86TNYEJNEPKUUMBJ","effectiveDate":"2018-05-31T23:59:59Z","offerTermCode":"MZU6U2429S","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"convertible","PurchaseOption":"All Upfront"}},"86TNYEJNEPKUUMBJ.R5XV2EPZQZ":{"priceDimensions":{"86TNYEJNEPKUUMBJ.R5XV2EPZQZ.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"86TNYEJNEPKUUMBJ.R5XV2EPZQZ.2TG2D8R56U","pricePerUnit":{"USD":"2768"}},"86TNYEJNEPKUUMBJ.R5XV2EPZQZ.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5d.2xlarge reserved instance applied","appliesTo":[],"rateCode":"86TNYEJNEPKUUMBJ.R5XV2EPZQZ.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.2350000000"}}},"sku":"86TNYEJNEPKUUMBJ","effectiveDate":"2018-05-31T23:59:59Z","offerTermCode":"R5XV2EPZQZ","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"convertible","PurchaseOption":"Partial Upfront"}},"86TNYEJNEPKUUMBJ.CUZHX8X6JH":{"priceDimensions":{"86TNYEJNEPKUUMBJ.CUZHX8X6JH.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5d.2xlarge reserved instance applied","appliesTo":[],"rateCode":"86TNYEJNEPKUUMBJ.CUZHX8X6JH.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.2880000000"}},"86TNYEJNEPKUUMBJ.CUZHX8X6JH.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesT ...
#  '{"product":{"productFamily":"Compute Instance","attributes":{"memory":"32 GiB","vcpu":"8","capacitystatus":"Used","instanceType":"t2.2xlarge","tenancy":"Shared","usagetype":"BoxUsage:t2.2xlarge","locationType":"AWS Region","storage":"EBS only","normalizationSizeFactor":"16","instanceFamily":"General purpose","operatingSystem":"RHEL","processorFeatures":"Intel AVX; Intel Turbo","servicecode":"AmazonEC2","physicalProcessor":"Intel Xeon Family","clockSpeed":"Up to 3.0 GHz","licenseModel":"No License required","ecu":"Variable","currentGeneration":"Yes","preInstalledSw":"NA","networkPerformance":"Moderate","location":"US East (N. Virginia)","servicename":"Amazon Elastic Compute Cloud","processorArchitecture":"64-bit","operation":"RunInstances:0010"},"sku":"A64H3T6VVR3C4SUA"},"serviceCode":"AmazonEC2","terms":{"OnDemand":{"A64H3T6VVR3C4SUA.JRTCKXETXF":{"priceDimensions":{"A64H3T6VVR3C4SUA.JRTCKXETXF.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"$0.5012 per On Demand RHEL t2.2xlarge Instance Hour","appliesTo":[],"rateCode":"A64H3T6VVR3C4SUA.JRTCKXETXF.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.5012000000"}}},"sku":"A64H3T6VVR3C4SUA","effectiveDate":"2018-05-01T00:00:00Z","offerTermCode":"JRTCKXETXF","termAttributes":{}}},"Reserved":{"A64H3T6VVR3C4SUA.6QCMYABX3D":{"priceDimensions":{"A64H3T6VVR3C4SUA.6QCMYABX3D.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"A64H3T6VVR3C4SUA.6QCMYABX3D.2TG2D8R56U","pricePerUnit":{"USD":"3019"}},"A64H3T6VVR3C4SUA.6QCMYABX3D.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), t2.2xlarge reserved instance applied","appliesTo":[],"rateCode":"A64H3T6VVR3C4SUA.6QCMYABX3D.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.0000000000"}}},"sku":"A64H3T6VVR3C4SUA","effectiveDate":"2017-09-30T23:59:59Z","offerTermCode":"6QCMYABX3D","termAttributes":{"LeaseContractLength":"1yr","OfferingClass":"standard","PurchaseOption":"All Upfront"}},"A64H3T6VVR3C4SUA.VJWZNREJX2":{"priceDimensions":{"A64H3T6VVR3C4SUA.VJWZNREJX2.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), t2.2xlarge reserved instance applied","appliesTo":[],"rateCode":"A64H3T6VVR3C4SUA.VJWZNREJX2.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.0000000000"}},"A64H3T6VVR3C4SUA.VJWZNREJX2.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"A64H3T6VVR3C4SUA.VJWZNREJX2.2TG2D8R56U","pricePerUnit":{"USD":"3301"}}},"sku":"A64H3T6VVR3C4SUA","effectiveDate":"2017-10-31T23:59:59Z","offerTermCode":"VJWZNREJX2","termAttributes":{"LeaseContractLength":"1yr","OfferingClass":"convertible","PurchaseOption":"All Upfront"}},"A64H3T6VVR3C4SUA.HU7G6KETJZ":{"priceDimensions":{"A64H3T6VVR3C4SUA.HU7G6KETJZ.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"A64H3T6VVR3C4SUA.HU7G6KETJZ.2TG2D8R56U","pricePerUnit":{"USD":"959"}},"A64H3T6VVR3C4SUA.HU7G6KETJZ.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), t2.2xlarge reserved instance applied","appliesTo":[],"rateCode":"A64H3T6VVR3C4SUA.HU7G6KETJZ.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.2395000000"}}},"sku":"A64H3T6VVR3C4SUA","effectiveDate":"2017-09-30T23:59:59Z","offerTermCode":"HU7G6KETJZ","termAttributes":{"LeaseContractLength":"1yr","OfferingClass":"standard","PurchaseOption":"Partial Upfront"}},"A64H3T6VVR3C4SUA.BPH4J8HBKS":{"priceDimensions":{"A64H3T6VVR3C4SUA.BPH4J8HBKS.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), t2.2xlarge reserved instance applied","appliesTo":[],"rateCode":"A64H3T6VVR3C4SUA.BPH4J8HBKS.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.2904000000"}}},"sku":"A64H3T6VVR3C4SUA","effectiveDate":"2017-09-30T23:59:59Z","offerTermCode":"BPH4J8HBKS","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"standard","PurchaseOption":"No Upfront"}},"A64H3T6VVR3C4SUA. ...
#  '{"product":{"productFamily":"Compute Instance","attributes":{"memory":"8 GiB","vcpu":"2","capacitystatus":"Used","instanceType":"t2.large","tenancy":"Shared","usagetype":"BoxUsage:t2.large","locationType":"AWS Region","storage":"EBS only","normalizationSizeFactor":"4","instanceFamily":"General purpose","operatingSystem":"RHEL","processorFeatures":"Intel AVX; Intel Turbo","servicecode":"AmazonEC2","physicalProcessor":"Intel Xeon Family","clockSpeed":"Up to 3.0 GHz","licenseModel":"No License required","ecu":"Variable","currentGeneration":"Yes","preInstalledSw":"NA","networkPerformance":"Low to Moderate","location":"US East (N. Virginia)","servicename":"Amazon Elastic Compute Cloud","processorArchitecture":"64-bit","operation":"RunInstances:0010"},"sku":"CE5UXUUUXVX4BZXY"},"serviceCode":"AmazonEC2","terms":{"OnDemand":{"CE5UXUUUXVX4BZXY.JRTCKXETXF":{"priceDimensions":{"CE5UXUUUXVX4BZXY.JRTCKXETXF.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"$0.1528 per On Demand RHEL t2.large Instance Hour","appliesTo":[],"rateCode":"CE5UXUUUXVX4BZXY.JRTCKXETXF.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.1528000000"}}},"sku":"CE5UXUUUXVX4BZXY","effectiveDate":"2018-05-01T00:00:00Z","offerTermCode":"JRTCKXETXF","termAttributes":{}}},"Reserved":{"CE5UXUUUXVX4BZXY.MZU6U2429S":{"priceDimensions":{"CE5UXUUUXVX4BZXY.MZU6U2429S.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"CE5UXUUUXVX4BZXY.MZU6U2429S.2TG2D8R56U","pricePerUnit":{"USD":"2676"}},"CE5UXUUUXVX4BZXY.MZU6U2429S.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), t2.large reserved instance applied","appliesTo":[],"rateCode":"CE5UXUUUXVX4BZXY.MZU6U2429S.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.0000000000"}}},"sku":"CE5UXUUUXVX4BZXY","effectiveDate":"2017-09-30T23:59:59Z","offerTermCode":"MZU6U2429S","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"convertible","PurchaseOption":"All Upfront"}},"CE5UXUUUXVX4BZXY.38NPMPTW36":{"priceDimensions":{"CE5UXUUUXVX4BZXY.38NPMPTW36.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), t2.large reserved instance applied","appliesTo":[],"rateCode":"CE5UXUUUXVX4BZXY.38NPMPTW36.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.0786000000"}},"CE5UXUUUXVX4BZXY.38NPMPTW36.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"CE5UXUUUXVX4BZXY.38NPMPTW36.2TG2D8R56U","pricePerUnit":{"USD":"488"}}},"sku":"CE5UXUUUXVX4BZXY","effectiveDate":"2017-09-30T23:59:59Z","offerTermCode":"38NPMPTW36","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"standard","PurchaseOption":"Partial Upfront"}},"CE5UXUUUXVX4BZXY.Z2E3P23VKM":{"priceDimensions":{"CE5UXUUUXVX4BZXY.Z2E3P23VKM.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), t2.large reserved instance applied","appliesTo":[],"rateCode":"CE5UXUUUXVX4BZXY.Z2E3P23VKM.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.1061000000"}}},"sku":"CE5UXUUUXVX4BZXY","effectiveDate":"2017-09-30T23:59:59Z","offerTermCode":"Z2E3P23VKM","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"convertible","PurchaseOption":"No Upfront"}},"CE5UXUUUXVX4BZXY.NQ3QZPMQV9":{"priceDimensions":{"CE5UXUUUXVX4BZXY.NQ3QZPMQV9.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"CE5UXUUUXVX4BZXY.NQ3QZPMQV9.2TG2D8R56U","pricePerUnit":{"USD":"2494"}},"CE5UXUUUXVX4BZXY.NQ3QZPMQV9.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), t2.large reserved instance applied","appliesTo":[],"rateCode":"CE5UXUUUXVX4BZXY.NQ3QZPMQV9.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.0000000000"}}},"sku":"CE5UXUUUXVX4BZXY","effectiveDate":"2017-09-30T23:59:59Z","offerTermCode":"NQ3QZPMQV9","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"standard","PurchaseOption":"All Upfront"}},"CE5UXUUUXVX4BZXY.R5XV2E ...
#  '{"product":{"productFamily":"Compute Instance","attributes":{"enhancedNetworkingSupported":"Yes","memory":"8 GiB","dedicatedEbsThroughput":"Upto 2120 Mbps","vcpu":"2","capacitystatus":"Used","locationType":"AWS Region","storage":"EBS only","instanceFamily":"General purpose","operatingSystem":"RHEL","physicalProcessor":"Intel Xeon Platinum 8175","clockSpeed":"2.5 GHz","ecu":"10","networkPerformance":"Up to 10 Gigabit","servicename":"Amazon Elastic Compute Cloud","instanceType":"m5.large","tenancy":"Shared","usagetype":"BoxUsage:m5.large","normalizationSizeFactor":"4","processorFeatures":"Intel AVX, Intel AVX2, Intel AVX512, Intel Turbo","servicecode":"AmazonEC2","licenseModel":"No License required","currentGeneration":"Yes","preInstalledSw":"NA","location":"US East (N. Virginia)","processorArchitecture":"64-bit","operation":"RunInstances:0010"},"sku":"DZBZFBHFHVERPMQZ"},"serviceCode":"AmazonEC2","terms":{"OnDemand":{"DZBZFBHFHVERPMQZ.JRTCKXETXF":{"priceDimensions":{"DZBZFBHFHVERPMQZ.JRTCKXETXF.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"$0.156 per On Demand RHEL m5.large Instance Hour","appliesTo":[],"rateCode":"DZBZFBHFHVERPMQZ.JRTCKXETXF.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.1560000000"}}},"sku":"DZBZFBHFHVERPMQZ","effectiveDate":"2018-05-01T00:00:00Z","offerTermCode":"JRTCKXETXF","termAttributes":{}}},"Reserved":{"DZBZFBHFHVERPMQZ.Z2E3P23VKM":{"priceDimensions":{"DZBZFBHFHVERPMQZ.Z2E3P23VKM.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5.large reserved instance applied","appliesTo":[],"rateCode":"DZBZFBHFHVERPMQZ.Z2E3P23VKM.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.1090000000"}}},"sku":"DZBZFBHFHVERPMQZ","effectiveDate":"2017-12-31T23:59:59Z","offerTermCode":"Z2E3P23VKM","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"convertible","PurchaseOption":"No Upfront"}},"DZBZFBHFHVERPMQZ.NQ3QZPMQV9":{"priceDimensions":{"DZBZFBHFHVERPMQZ.NQ3QZPMQV9.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"DZBZFBHFHVERPMQZ.NQ3QZPMQV9.2TG2D8R56U","pricePerUnit":{"USD":"2545"}},"DZBZFBHFHVERPMQZ.NQ3QZPMQV9.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5.large reserved instance applied","appliesTo":[],"rateCode":"DZBZFBHFHVERPMQZ.NQ3QZPMQV9.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.0000000000"}}},"sku":"DZBZFBHFHVERPMQZ","effectiveDate":"2017-10-31T23:59:59Z","offerTermCode":"NQ3QZPMQV9","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"standard","PurchaseOption":"All Upfront"}},"DZBZFBHFHVERPMQZ.BPH4J8HBKS":{"priceDimensions":{"DZBZFBHFHVERPMQZ.BPH4J8HBKS.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5.large reserved instance applied","appliesTo":[],"rateCode":"DZBZFBHFHVERPMQZ.BPH4J8HBKS.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.1020000000"}}},"sku":"DZBZFBHFHVERPMQZ","effectiveDate":"2017-10-31T23:59:59Z","offerTermCode":"BPH4J8HBKS","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"standard","PurchaseOption":"No Upfront"}},"DZBZFBHFHVERPMQZ.6QCMYABX3D":{"priceDimensions":{"DZBZFBHFHVERPMQZ.6QCMYABX3D.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"DZBZFBHFHVERPMQZ.6QCMYABX3D.2TG2D8R56U","pricePerUnit":{"USD":"1027"}},"DZBZFBHFHVERPMQZ.6QCMYABX3D.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5.large reserved instance applied","appliesTo":[],"rateCode":"DZBZFBHFHVERPMQZ.6QCMYABX3D.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.0000000000"}}},"sku":"DZBZFBHFHVERPMQZ","effectiveDate":"2017-10-31T23:59:59Z","offerTermCode":"6QCMYABX3D","termAttributes":{"LeaseContractLength":"1yr","OfferingClass":"standard","PurchaseOption":"All Upfront"}},"DZBZFBHFHVERPMQZ.38NPMPTW36":{"priceDimensions":{"DZBZFBHFHVERPMQZ.38NPMPTW36.2TG2D8R56U":{"unit":"Quantity","descrip ...
#  '{"product":{"productFamily":"Compute Instance","attributes":{"enhancedNetworkingSupported":"Yes","memory":"384 GiB","dedicatedEbsThroughput":"12000 Mbps","vcpu":"96","capacitystatus":"None","locationType":"AWS Region","storage":"4 x 900","instanceFamily":"General purpose","operatingSystem":"RHEL","physicalProcessor":"Intel Xeon Platinum 8175","clockSpeed":"2.5 GHz","ecu":"345","networkPerformance":"25 Gigabit","servicename":"Amazon Elastic Compute Cloud","instanceType":"m5d.24xlarge","tenancy":"Shared","usagetype":"BoxUsage:m5d.24xlarge","normalizationSizeFactor":"192","processorFeatures":"Intel AVX, Intel AVX2, Intel AVX512, Intel Turbo","servicecode":"AmazonEC2","licenseModel":"No License required","currentGeneration":"Yes","preInstalledSw":"NA","location":"US East (N. Virginia)","processorArchitecture":"64-bit","operation":"RunInstances:0010"},"sku":"EBDV6YJFC8EDK23Y"},"serviceCode":"AmazonEC2","terms":{"OnDemand":{"EBDV6YJFC8EDK23Y.JRTCKXETXF":{"priceDimensions":{"EBDV6YJFC8EDK23Y.JRTCKXETXF.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"$5.554 per On Demand RHEL m5d.24xlarge Instance Hour","appliesTo":[],"rateCode":"EBDV6YJFC8EDK23Y.JRTCKXETXF.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"5.5540000000"}}},"sku":"EBDV6YJFC8EDK23Y","effectiveDate":"2018-05-01T00:00:00Z","offerTermCode":"JRTCKXETXF","termAttributes":{}}},"Reserved":{"EBDV6YJFC8EDK23Y.HU7G6KETJZ":{"priceDimensions":{"EBDV6YJFC8EDK23Y.HU7G6KETJZ.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"EBDV6YJFC8EDK23Y.HU7G6KETJZ.2TG2D8R56U","pricePerUnit":{"USD":"14407"}},"EBDV6YJFC8EDK23Y.HU7G6KETJZ.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5d.24xlarge reserved instance applied","appliesTo":[],"rateCode":"EBDV6YJFC8EDK23Y.HU7G6KETJZ.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"1.7750000000"}}},"sku":"EBDV6YJFC8EDK23Y","effectiveDate":"2018-05-31T23:59:59Z","offerTermCode":"HU7G6KETJZ","termAttributes":{"LeaseContractLength":"1yr","OfferingClass":"standard","PurchaseOption":"Partial Upfront"}},"EBDV6YJFC8EDK23Y.38NPMPTW36":{"priceDimensions":{"EBDV6YJFC8EDK23Y.38NPMPTW36.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"EBDV6YJFC8EDK23Y.38NPMPTW36.2TG2D8R56U","pricePerUnit":{"USD":"28882"}},"EBDV6YJFC8EDK23Y.38NPMPTW36.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5d.24xlarge reserved instance applied","appliesTo":[],"rateCode":"EBDV6YJFC8EDK23Y.38NPMPTW36.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"1.2290000000"}}},"sku":"EBDV6YJFC8EDK23Y","effectiveDate":"2018-05-31T23:59:59Z","offerTermCode":"38NPMPTW36","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"standard","PurchaseOption":"Partial Upfront"}},"EBDV6YJFC8EDK23Y.Z2E3P23VKM":{"priceDimensions":{"EBDV6YJFC8EDK23Y.Z2E3P23VKM.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5d.24xlarge reserved instance applied","appliesTo":[],"rateCode":"EBDV6YJFC8EDK23Y.Z2E3P23VKM.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"2.8600000000"}}},"sku":"EBDV6YJFC8EDK23Y","effectiveDate":"2018-05-31T23:59:59Z","offerTermCode":"Z2E3P23VKM","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"convertible","PurchaseOption":"No Upfront"}},"EBDV6YJFC8EDK23Y.R5XV2EPZQZ":{"priceDimensions":{"EBDV6YJFC8EDK23Y.R5XV2EPZQZ.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"EBDV6YJFC8EDK23Y.R5XV2EPZQZ.2TG2D8R56U","pricePerUnit":{"USD":"33214"}},"EBDV6YJFC8EDK23Y.R5XV2EPZQZ.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5d.24xlarge reserved instance applied","appliesTo":[],"rateCode":"EBDV6YJFC8EDK23Y.R5XV2EPZQZ.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"1.3940000000"}}},"sku":"EBDV6YJFC8EDK23Y","effectiveDate":"2018-05-31T23:59:59Z","offerTermCode":"R5XV2EPZQZ","te ...
#  '{"product":{"productFamily":"Compute Instance","attributes":{"enhancedNetworkingSupported":"Yes","memory":"32 GiB","dedicatedEbsThroughput":"1000 Mbps","vcpu":"8","capacitystatus":"Used","locationType":"AWS Region","storage":"EBS only","instanceFamily":"General purpose","operatingSystem":"RHEL","physicalProcessor":"Intel Xeon E5-2676 v3 (Haswell)","clockSpeed":"2.4 GHz","ecu":"26","networkPerformance":"High","servicename":"Amazon Elastic Compute Cloud","instanceType":"m4.2xlarge","tenancy":"Shared","usagetype":"BoxUsage:m4.2xlarge","normalizationSizeFactor":"16","processorFeatures":"Intel AVX; Intel AVX2; Intel Turbo","servicecode":"AmazonEC2","licenseModel":"No License required","currentGeneration":"Yes","preInstalledSw":"NA","location":"US East (N. Virginia)","processorArchitecture":"64-bit","operation":"RunInstances:0010"},"sku":"F3MSPCKJ74QTGZ7J"},"serviceCode":"AmazonEC2","terms":{"OnDemand":{"F3MSPCKJ74QTGZ7J.JRTCKXETXF":{"priceDimensions":{"F3MSPCKJ74QTGZ7J.JRTCKXETXF.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"$0.53 per On Demand RHEL m4.2xlarge Instance Hour","appliesTo":[],"rateCode":"F3MSPCKJ74QTGZ7J.JRTCKXETXF.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.5300000000"}}},"sku":"F3MSPCKJ74QTGZ7J","effectiveDate":"2018-05-01T00:00:00Z","offerTermCode":"JRTCKXETXF","termAttributes":{}}},"Reserved":{"F3MSPCKJ74QTGZ7J.CUZHX8X6JH":{"priceDimensions":{"F3MSPCKJ74QTGZ7J.CUZHX8X6JH.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m4.2xlarge reserved instance applied","appliesTo":[],"rateCode":"F3MSPCKJ74QTGZ7J.CUZHX8X6JH.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.2657000000"}},"F3MSPCKJ74QTGZ7J.CUZHX8X6JH.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"F3MSPCKJ74QTGZ7J.CUZHX8X6JH.2TG2D8R56U","pricePerUnit":{"USD":"1189"}}},"sku":"F3MSPCKJ74QTGZ7J","effectiveDate":"2017-10-31T23:59:59Z","offerTermCode":"CUZHX8X6JH","termAttributes":{"LeaseContractLength":"1yr","OfferingClass":"convertible","PurchaseOption":"Partial Upfront"}},"F3MSPCKJ74QTGZ7J.4NA7Y494T4":{"priceDimensions":{"F3MSPCKJ74QTGZ7J.4NA7Y494T4.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m4.2xlarge reserved instance applied","appliesTo":[],"rateCode":"F3MSPCKJ74QTGZ7J.4NA7Y494T4.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.3778000000"}}},"sku":"F3MSPCKJ74QTGZ7J","effectiveDate":"2017-04-30T23:59:59Z","offerTermCode":"4NA7Y494T4","termAttributes":{"LeaseContractLength":"1yr","OfferingClass":"standard","PurchaseOption":"No Upfront"}},"F3MSPCKJ74QTGZ7J.7NE97W5U4E":{"priceDimensions":{"F3MSPCKJ74QTGZ7J.7NE97W5U4E.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m4.2xlarge reserved instance applied","appliesTo":[],"rateCode":"F3MSPCKJ74QTGZ7J.7NE97W5U4E.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.4150000000"}}},"sku":"F3MSPCKJ74QTGZ7J","effectiveDate":"2017-10-31T23:59:59Z","offerTermCode":"7NE97W5U4E","termAttributes":{"LeaseContractLength":"1yr","OfferingClass":"convertible","PurchaseOption":"No Upfront"}},"F3MSPCKJ74QTGZ7J.R5XV2EPZQZ":{"priceDimensions":{"F3MSPCKJ74QTGZ7J.R5XV2EPZQZ.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"F3MSPCKJ74QTGZ7J.R5XV2EPZQZ.2TG2D8R56U","pricePerUnit":{"USD":"2418"}},"F3MSPCKJ74QTGZ7J.R5XV2EPZQZ.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m4.2xlarge reserved instance applied","appliesTo":[],"rateCode":"F3MSPCKJ74QTGZ7J.R5XV2EPZQZ.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.2220000000"}}},"sku":"F3MSPCKJ74QTGZ7J","effectiveDate":"2017-04-30T23:59:59Z","offerTermCode":"R5XV2EPZQZ","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"convertible","PurchaseOption":"Partial Upfront"}},"F3MSPCKJ74QTGZ7J.38NPMPTW36":{"priceDimensions":{"F3MSPCKJ74QTGZ7J.38NPMPTW36.2TG2D8R56U":{"unit":"Quantity","de ...
#  '{"product":{"productFamily":"Compute Instance","attributes":{"enhancedNetworkingSupported":"Yes","memory":"192 GiB","dedicatedEbsThroughput":"6000 Mbps","vcpu":"48","capacitystatus":"Used","locationType":"AWS Region","storage":"EBS only","instanceFamily":"General purpose","operatingSystem":"RHEL","physicalProcessor":"Intel Xeon Platinum 8175","clockSpeed":"2.5 GHz","ecu":"173","networkPerformance":"10 Gigabit","servicename":"Amazon Elastic Compute Cloud","instanceType":"m5.12xlarge","tenancy":"Shared","usagetype":"BoxUsage:m5.12xlarge","normalizationSizeFactor":"96","processorFeatures":"Intel AVX, Intel AVX2, Intel AVX512, Intel Turbo","servicecode":"AmazonEC2","licenseModel":"No License required","currentGeneration":"Yes","preInstalledSw":"NA","location":"US East (N. Virginia)","processorArchitecture":"64-bit","operation":"RunInstances:0010"},"sku":"H2X3RHK4BQ33DV66"},"serviceCode":"AmazonEC2","terms":{"OnDemand":{"H2X3RHK4BQ33DV66.JRTCKXETXF":{"priceDimensions":{"H2X3RHK4BQ33DV66.JRTCKXETXF.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"$2.434 per On Demand RHEL m5.12xlarge Instance Hour","appliesTo":[],"rateCode":"H2X3RHK4BQ33DV66.JRTCKXETXF.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"2.4340000000"}}},"sku":"H2X3RHK4BQ33DV66","effectiveDate":"2018-05-01T00:00:00Z","offerTermCode":"JRTCKXETXF","termAttributes":{}}},"Reserved":{"H2X3RHK4BQ33DV66.7NE97W5U4E":{"priceDimensions":{"H2X3RHK4BQ33DV66.7NE97W5U4E.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5.12xlarge reserved instance applied","appliesTo":[],"rateCode":"H2X3RHK4BQ33DV66.7NE97W5U4E.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"1.8230000000"}}},"sku":"H2X3RHK4BQ33DV66","effectiveDate":"2017-10-31T23:59:59Z","offerTermCode":"7NE97W5U4E","termAttributes":{"LeaseContractLength":"1yr","OfferingClass":"convertible","PurchaseOption":"No Upfront"}},"H2X3RHK4BQ33DV66.CUZHX8X6JH":{"priceDimensions":{"H2X3RHK4BQ33DV66.CUZHX8X6JH.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5.12xlarge reserved instance applied","appliesTo":[],"rateCode":"H2X3RHK4BQ33DV66.CUZHX8X6JH.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.9360000000"}},"H2X3RHK4BQ33DV66.CUZHX8X6JH.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"H2X3RHK4BQ33DV66.CUZHX8X6JH.2TG2D8R56U","pricePerUnit":{"USD":"7061"}}},"sku":"H2X3RHK4BQ33DV66","effectiveDate":"2017-10-31T23:59:59Z","offerTermCode":"CUZHX8X6JH","termAttributes":{"LeaseContractLength":"1yr","OfferingClass":"convertible","PurchaseOption":"Partial Upfront"}},"H2X3RHK4BQ33DV66.6QCMYABX3D":{"priceDimensions":{"H2X3RHK4BQ33DV66.6QCMYABX3D.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"H2X3RHK4BQ33DV66.6QCMYABX3D.2TG2D8R56U","pricePerUnit":{"USD":"13173"}},"H2X3RHK4BQ33DV66.6QCMYABX3D.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5.12xlarge reserved instance applied","appliesTo":[],"rateCode":"H2X3RHK4BQ33DV66.6QCMYABX3D.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.0000000000"}}},"sku":"H2X3RHK4BQ33DV66","effectiveDate":"2017-10-31T23:59:59Z","offerTermCode":"6QCMYABX3D","termAttributes":{"LeaseContractLength":"1yr","OfferingClass":"standard","PurchaseOption":"All Upfront"}},"H2X3RHK4BQ33DV66.38NPMPTW36":{"priceDimensions":{"H2X3RHK4BQ33DV66.38NPMPTW36.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"H2X3RHK4BQ33DV66.38NPMPTW36.2TG2D8R56U","pricePerUnit":{"USD":"12362"}},"H2X3RHK4BQ33DV66.38NPMPTW36.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5.12xlarge reserved instance applied","appliesTo":[],"rateCode":"H2X3RHK4BQ33DV66.38NPMPTW36.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.6000000000"}}},"sku":"H2X3RHK4BQ33DV66","effectiveDate":"2017-12-31T23:59:59Z","offerTermCode":"38NPMPTW36","termAttribut ...
# ...
#  '{"product":{"productFamily":"Compute Instance","attributes":{"memory":"16 GiB","vcpu":"4","capacitystatus":"Used","instanceType":"t2.xlarge","tenancy":"Shared","usagetype":"BoxUsage:t2.xlarge","locationType":"AWS Region","storage":"EBS only","normalizationSizeFactor":"8","instanceFamily":"General purpose","operatingSystem":"RHEL","processorFeatures":"Intel AVX; Intel Turbo","servicecode":"AmazonEC2","physicalProcessor":"Intel Xeon Family","clockSpeed":"Up to 3.0 GHz","licenseModel":"No License required","ecu":"Variable","currentGeneration":"Yes","preInstalledSw":"NA","networkPerformance":"Moderate","location":"US East (N. Virginia)","servicename":"Amazon Elastic Compute Cloud","processorArchitecture":"64-bit","operation":"RunInstances:0010"},"sku":"SCYNS2QNCRN89WMZ"},"serviceCode":"AmazonEC2","terms":{"OnDemand":{"SCYNS2QNCRN89WMZ.JRTCKXETXF":{"priceDimensions":{"SCYNS2QNCRN89WMZ.JRTCKXETXF.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"$0.2456 per On Demand RHEL t2.xlarge Instance Hour","appliesTo":[],"rateCode":"SCYNS2QNCRN89WMZ.JRTCKXETXF.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.2456000000"}}},"sku":"SCYNS2QNCRN89WMZ","effectiveDate":"2018-05-01T00:00:00Z","offerTermCode":"JRTCKXETXF","termAttributes":{}}},"Reserved":{"SCYNS2QNCRN89WMZ.CUZHX8X6JH":{"priceDimensions":{"SCYNS2QNCRN89WMZ.CUZHX8X6JH.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"SCYNS2QNCRN89WMZ.CUZHX8X6JH.2TG2D8R56U","pricePerUnit":{"USD":"552"}},"SCYNS2QNCRN89WMZ.CUZHX8X6JH.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), t2.xlarge reserved instance applied","appliesTo":[],"rateCode":"SCYNS2QNCRN89WMZ.CUZHX8X6JH.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.1230000000"}}},"sku":"SCYNS2QNCRN89WMZ","effectiveDate":"2017-10-31T23:59:59Z","offerTermCode":"CUZHX8X6JH","termAttributes":{"LeaseContractLength":"1yr","OfferingClass":"convertible","PurchaseOption":"Partial Upfront"}},"SCYNS2QNCRN89WMZ.4NA7Y494T4":{"priceDimensions":{"SCYNS2QNCRN89WMZ.4NA7Y494T4.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), t2.xlarge reserved instance applied","appliesTo":[],"rateCode":"SCYNS2QNCRN89WMZ.4NA7Y494T4.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.1750000000"}}},"sku":"SCYNS2QNCRN89WMZ","effectiveDate":"2017-09-30T23:59:59Z","offerTermCode":"4NA7Y494T4","termAttributes":{"LeaseContractLength":"1yr","OfferingClass":"standard","PurchaseOption":"No Upfront"}},"SCYNS2QNCRN89WMZ.7NE97W5U4E":{"priceDimensions":{"SCYNS2QNCRN89WMZ.7NE97W5U4E.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), t2.xlarge reserved instance applied","appliesTo":[],"rateCode":"SCYNS2QNCRN89WMZ.7NE97W5U4E.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.1922000000"}}},"sku":"SCYNS2QNCRN89WMZ","effectiveDate":"2017-10-31T23:59:59Z","offerTermCode":"7NE97W5U4E","termAttributes":{"LeaseContractLength":"1yr","OfferingClass":"convertible","PurchaseOption":"No Upfront"}},"SCYNS2QNCRN89WMZ.38NPMPTW36":{"priceDimensions":{"SCYNS2QNCRN89WMZ.38NPMPTW36.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), t2.xlarge reserved instance applied","appliesTo":[],"rateCode":"SCYNS2QNCRN89WMZ.38NPMPTW36.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.0971000000"}},"SCYNS2QNCRN89WMZ.38NPMPTW36.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"SCYNS2QNCRN89WMZ.38NPMPTW36.2TG2D8R56U","pricePerUnit":{"USD":"976"}}},"sku":"SCYNS2QNCRN89WMZ","effectiveDate":"2017-09-30T23:59:59Z","offerTermCode":"38NPMPTW36","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"standard","PurchaseOption":"Partial Upfront"}},"SCYNS2QNCRN89WMZ.R5XV2EPZQZ":{"priceDimensions":{"SCYNS2QNCRN89WMZ.R5XV2EPZQZ.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"SCYNS2QNCRN89WMZ.R5XV2EPZQZ.2TG2D8R56U","p ...
#  '{"product":{"productFamily":"Compute Instance","attributes":{"enhancedNetworkingSupported":"Yes","memory":"16 GiB","dedicatedEbsThroughput":"Upto 2120 Mbps","vcpu":"4","capacitystatus":"Used","locationType":"AWS Region","storage":"EBS only","instanceFamily":"General purpose","operatingSystem":"RHEL","physicalProcessor":"Intel Xeon Platinum 8175","clockSpeed":"2.5 GHz","ecu":"15","networkPerformance":"Up to 10 Gigabit","servicename":"Amazon Elastic Compute Cloud","instanceType":"m5.xlarge","tenancy":"Shared","usagetype":"BoxUsage:m5.xlarge","normalizationSizeFactor":"8","processorFeatures":"Intel AVX, Intel AVX2, Intel AVX512, Intel Turbo","servicecode":"AmazonEC2","licenseModel":"No License required","currentGeneration":"Yes","preInstalledSw":"NA","location":"US East (N. Virginia)","processorArchitecture":"64-bit","operation":"RunInstances:0010"},"sku":"X9Q63MGMWNUUK9K4"},"serviceCode":"AmazonEC2","terms":{"OnDemand":{"X9Q63MGMWNUUK9K4.JRTCKXETXF":{"priceDimensions":{"X9Q63MGMWNUUK9K4.JRTCKXETXF.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"$0.252 per On Demand RHEL m5.xlarge Instance Hour","appliesTo":[],"rateCode":"X9Q63MGMWNUUK9K4.JRTCKXETXF.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.2520000000"}}},"sku":"X9Q63MGMWNUUK9K4","effectiveDate":"2018-05-01T00:00:00Z","offerTermCode":"JRTCKXETXF","termAttributes":{}}},"Reserved":{"X9Q63MGMWNUUK9K4.R5XV2EPZQZ":{"priceDimensions":{"X9Q63MGMWNUUK9K4.R5XV2EPZQZ.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5.xlarge reserved instance applied","appliesTo":[],"rateCode":"X9Q63MGMWNUUK9K4.R5XV2EPZQZ.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.1050000000"}},"X9Q63MGMWNUUK9K4.R5XV2EPZQZ.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"X9Q63MGMWNUUK9K4.R5XV2EPZQZ.2TG2D8R56U","pricePerUnit":{"USD":"1185"}}},"sku":"X9Q63MGMWNUUK9K4","effectiveDate":"2017-10-31T23:59:59Z","offerTermCode":"R5XV2EPZQZ","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"convertible","PurchaseOption":"Partial Upfront"}},"X9Q63MGMWNUUK9K4.Z2E3P23VKM":{"priceDimensions":{"X9Q63MGMWNUUK9K4.Z2E3P23VKM.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5.xlarge reserved instance applied","appliesTo":[],"rateCode":"X9Q63MGMWNUUK9K4.Z2E3P23VKM.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.1570000000"}}},"sku":"X9Q63MGMWNUUK9K4","effectiveDate":"2017-10-31T23:59:59Z","offerTermCode":"Z2E3P23VKM","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"convertible","PurchaseOption":"No Upfront"}},"X9Q63MGMWNUUK9K4.BPH4J8HBKS":{"priceDimensions":{"X9Q63MGMWNUUK9K4.BPH4J8HBKS.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5.xlarge reserved instance applied","appliesTo":[],"rateCode":"X9Q63MGMWNUUK9K4.BPH4J8HBKS.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.1450000000"}}},"sku":"X9Q63MGMWNUUK9K4","effectiveDate":"2017-10-31T23:59:59Z","offerTermCode":"BPH4J8HBKS","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"standard","PurchaseOption":"No Upfront"}},"X9Q63MGMWNUUK9K4.NQ3QZPMQV9":{"priceDimensions":{"X9Q63MGMWNUUK9K4.NQ3QZPMQV9.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"X9Q63MGMWNUUK9K4.NQ3QZPMQV9.2TG2D8R56U","pricePerUnit":{"USD":"3514"}},"X9Q63MGMWNUUK9K4.NQ3QZPMQV9.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), m5.xlarge reserved instance applied","appliesTo":[],"rateCode":"X9Q63MGMWNUUK9K4.NQ3QZPMQV9.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.0000000000"}}},"sku":"X9Q63MGMWNUUK9K4","effectiveDate":"2017-10-31T23:59:59Z","offerTermCode":"NQ3QZPMQV9","termAttributes":{"LeaseContractLength":"3yr","OfferingClass":"standard","PurchaseOption":"All Upfront"}},"X9Q63MGMWNUUK9K4.VJWZNREJX2":{"priceDimensions":{"X9Q63MGMWNUUK9K4.VJWZNREJX2.2TG2D8R56U":{"unit":"Qua ...
#  '{"product":{"productFamily":"Compute Instance","attributes":{"memory":"1 GiB","vcpu":"1","capacitystatus":"Used","instanceType":"t2.micro","tenancy":"Shared","usagetype":"BoxUsage:t2.micro","locationType":"AWS Region","storage":"EBS only","normalizationSizeFactor":"0.5","instanceFamily":"General purpose","operatingSystem":"RHEL","processorFeatures":"Intel AVX; Intel Turbo","servicecode":"AmazonEC2","physicalProcessor":"Intel Xeon Family","clockSpeed":"Up to 3.3 GHz","licenseModel":"No License required","ecu":"Variable","currentGeneration":"Yes","preInstalledSw":"NA","networkPerformance":"Low to Moderate","location":"US East (N. Virginia)","servicename":"Amazon Elastic Compute Cloud","processorArchitecture":"32-bit or 64-bit","operation":"RunInstances:0010"},"sku":"ZY733QB4MX5V3J68"},"serviceCode":"AmazonEC2","terms":{"OnDemand":{"ZY733QB4MX5V3J68.JRTCKXETXF":{"priceDimensions":{"ZY733QB4MX5V3J68.JRTCKXETXF.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"$0.0716 per On Demand RHEL t2.micro Instance Hour","appliesTo":[],"rateCode":"ZY733QB4MX5V3J68.JRTCKXETXF.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.0716000000"}}},"sku":"ZY733QB4MX5V3J68","effectiveDate":"2018-05-01T00:00:00Z","offerTermCode":"JRTCKXETXF","termAttributes":{}}},"Reserved":{"ZY733QB4MX5V3J68.4NA7Y494T4":{"priceDimensions":{"ZY733QB4MX5V3J68.4NA7Y494T4.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), t2.micro reserved instance applied","appliesTo":[],"rateCode":"ZY733QB4MX5V3J68.4NA7Y494T4.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.0672000000"}}},"sku":"ZY733QB4MX5V3J68","effectiveDate":"2017-09-30T23:59:59Z","offerTermCode":"4NA7Y494T4","termAttributes":{"LeaseContractLength":"1yr","OfferingClass":"standard","PurchaseOption":"No Upfront"}},"ZY733QB4MX5V3J68.HU7G6KETJZ":{"priceDimensions":{"ZY733QB4MX5V3J68.HU7G6KETJZ.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"ZY733QB4MX5V3J68.HU7G6KETJZ.2TG2D8R56U","pricePerUnit":{"USD":"30"}},"ZY733QB4MX5V3J68.HU7G6KETJZ.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), t2.micro reserved instance applied","appliesTo":[],"rateCode":"ZY733QB4MX5V3J68.HU7G6KETJZ.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.0634000000"}}},"sku":"ZY733QB4MX5V3J68","effectiveDate":"2017-09-30T23:59:59Z","offerTermCode":"HU7G6KETJZ","termAttributes":{"LeaseContractLength":"1yr","OfferingClass":"standard","PurchaseOption":"Partial Upfront"}},"ZY733QB4MX5V3J68.7NE97W5U4E":{"priceDimensions":{"ZY733QB4MX5V3J68.7NE97W5U4E.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), t2.micro reserved instance applied","appliesTo":[],"rateCode":"ZY733QB4MX5V3J68.7NE97W5U4E.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.0683000000"}}},"sku":"ZY733QB4MX5V3J68","effectiveDate":"2017-10-31T23:59:59Z","offerTermCode":"7NE97W5U4E","termAttributes":{"LeaseContractLength":"1yr","OfferingClass":"convertible","PurchaseOption":"No Upfront"}},"ZY733QB4MX5V3J68.CUZHX8X6JH":{"priceDimensions":{"ZY733QB4MX5V3J68.CUZHX8X6JH.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"ZY733QB4MX5V3J68.CUZHX8X6JH.2TG2D8R56U","pricePerUnit":{"USD":"34"}},"ZY733QB4MX5V3J68.CUZHX8X6JH.6YS6EN2CT7":{"unit":"Hrs","endRange":"Inf","description":"Red Hat Enterprise Linux (Amazon VPC), t2.micro reserved instance applied","appliesTo":[],"rateCode":"ZY733QB4MX5V3J68.CUZHX8X6JH.6YS6EN2CT7","beginRange":"0","pricePerUnit":{"USD":"0.0639000000"}}},"sku":"ZY733QB4MX5V3J68","effectiveDate":"2017-10-31T23:59:59Z","offerTermCode":"CUZHX8X6JH","termAttributes":{"LeaseContractLength":"1yr","OfferingClass":"convertible","PurchaseOption":"Partial Upfront"}},"ZY733QB4MX5V3J68.NQ3QZPMQV9":{"priceDimensions":{"ZY733QB4MX5V3J68.NQ3QZPMQV9.2TG2D8R56U":{"unit":"Quantity","description":"Upfront Fee","appliesTo":[],"rateCode":"ZY733QB4MX5V3J68.NQ3QZPMQV9.2TG2D ...

# %%
dfInstanceList
# Out:
# Empty DataFrame
# Columns: [family, instanceType, memory, one_hr_rate, one_yr_rate, three_yr_rate, vcpu]
# Index: []

# %%
instanceType
# Out:
# 'm5d.12xlarge'
